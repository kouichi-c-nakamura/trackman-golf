# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

CSV_PATH = "stitched_golf_data_June17.csv"

df = pd.read_csv(CSV_PATH)

# %%
print(df.shape[0])
print(df['キャリー (yds)'].max())
print(df['最高到達点 (yds)'].max())
# Out:
# 49
# 113
# 19

# %%
from pathlib import Path
import sys

# ノートブックを実行しているディレクトリ (例: .../2026/2026-08-12)
current_dir = Path.cwd()

# 2階層上のディレクトリ（plot_trackman_golf.py がある場所）を取得
project_root = current_dir.parents[1]

# sys.path に追加
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# インポートと呼び出し
from plot_trackman_golf import plot_golf_shots

plot_golf_shots("stitched_golf_data_June17.csv", mode="two_panel", save_path="2026-06-17_range_2rows.png", xlim=[0, 57], title="2026-06-17");

plot_golf_shots("stitched_golf_data_June17.csv", mode="single", save_path="2026-06-17_range_single.png", xlim=[0, 57], title="2026-06-17");
