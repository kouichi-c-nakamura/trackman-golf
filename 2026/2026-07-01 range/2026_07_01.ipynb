# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

CSV_PATH = "data_2026-07-01.csv"

df = pd.read_csv(CSV_PATH)

# %%
print(df.shape[0])
print(df['キャリー (yds)'].max())
print(df['最高到達点 (yds)'].max())
# Out:
# 109
# 112
# 22

# %%
from pathlib import Path
import sys

# ノートブックを実行しているディレクトリ (例: .../2026/2026-08-12)
current_dir = Path.cwd()

# 2階層上のディレクトリ（plot_trackman_golf.py がある場所）を取得
project_root = current_dir.parents[1]

# sys.path に追加
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# インポートと呼び出し
from plot_trackman_golf import plot_golf_shots

plot_golf_shots("data_2026-07-01.csv", mode="two_panel", save_path="2026-07-01_range_2rows.png", xlim=[0, 115], title="2026-07-01");

plot_golf_shots("data_2026-07-01.csv", mode="single", save_path="2026-07-01_range_single.png", xlim=[0, 115], title="2026-07-01");
