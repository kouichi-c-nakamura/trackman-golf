# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

CSV_PATH = "golf_shot_data_combined.csv"

df = pd.read_csv(CSV_PATH)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(df.shape[0])
print(df['キャリー (yds)'].max())
print(df['最高到達点 (yds)'].max())
# Out:
# 90
# 116
# 26

# %%
from pathlib import Path
import sys

# ノートブックを実行しているディレクトリ (例: .../2026/2026-08-12)
current_dir = Path.cwd()

# 2階層上のディレクトリ（plot_trackman_golf.py がある場所）を取得
project_root = current_dir.parents[1]

# sys.path に追加
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# インポートと呼び出し
from plot_trackman_golf import plot_golf_shots

plot_golf_shots("golf_shot_data_combined.csv", mode="two_panel", save_path="2026-06-10_range_2rows.png", xlim=[0, 57], title="2026-06-10");

plot_golf_shots("golf_shot_data_combined.csv", mode="single", save_path="2026-06-10_range_single.png", xlim=[0, 57], title="2026-06-10");
