# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

CSV_PATH = "data.csv"

date_str = "2025-12-01"

df = pd.read_csv(CSV_PATH)

# %%
print(df.shape[0])
print(df['キャリー (yds)'].max())
print(df['最高到達点 (yds)'].max())
# Out:
# 83
# 98
# 18

# %%
from pathlib import Path
import sys

# ノートブックを実行しているディレクトリ (例: .../2026/2026-08-12)
current_dir = Path.cwd()

# 2階層上のディレクトリ（plot_trackman_golf.py がある場所）を取得
project_root = current_dir.parents[1]

# sys.path に追加
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# インポートと呼び出し
from plot_trackman_golf import plot_golf_shots

plot_golf_shots(CSV_PATH, mode="two_panel", save_path=date_str+"_range_2rows.png", title=date_str);

plot_golf_shots(CSV_PATH, mode="single", save_path=date_str+"_range_single.png", title=date_str);
